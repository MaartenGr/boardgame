# %%
import pandas as pd

# %%
df = pd.read_excel("matches.xlsx")

# %%
df
# Out:
#           Date Players         Game     Scores Winner       Version
# 0   2018-11-18     I+M        Qwixx    I77+M77    I+M        Normal
# 1   2018-11-18     I+M        Qwixx   I104+M65      I        Normal
# 2   2018-11-18     I+M        Qwixx    I96+M62      I        Normal
# 3   2018-11-18     I+M         Mind      LVL10    NaN        Normal
# 4   2018-11-18     I+M         Mind       LVL4    NaN        Normal
# ..         ...     ...          ...        ...    ...           ...
# 215 2019-09-22     I+M         Mind      LVL12    I+M        Normal
# 216 2019-09-22     I+M  Regenwormen     I4+M18      M        Normal
# 217 2019-10-06     I+M        Qwixx  I135+M120      I  Treden Ia+Me
# 218 2019-10-12     I+M       Jaipur    I92+M81      I        Normal
# 219 2019-10-12     I+M       Jaipur    I79+M76      I        Normal
#
# [220 rows x 6 columns]
